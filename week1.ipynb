# %% [markdown]
# # 1. 머신러닝이란
#   : 머신이 데이터를 보고 학습하게 하는 방법
#
#   : 프로그래머가 직접 만든 규칙 대신 컴퓨터가 데이터를 보고 자동으로 이런 규칙을 학습하는 것
#
#   : 명시적으로 프로그램 되는 것이 아닌 훈련되는 것

# %% [markdown]
# # 2. 마크다운
# ---
# # 큰 제목
# ## 중간 제목
# ### 작은 제목
# ---
# * 별표는 번호 없는 목록
# 1. 번호 있는 목록
